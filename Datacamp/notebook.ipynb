# %% [markdown]
# ![Movie popcorn on red background](redpopcorn.jpg)

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry. Our friend has also been brushing up on their Python skills and has taken a first crack at a CSV file containing Netflix data. They believe that the average duration of movies has been declining. Using your friends initial research, you'll delve into the Netflix data to see if you can determine whether movie lengths are actually getting shorter and explain some of the contributing factors, if any.
#
# You have been supplied with the dataset `netflix_data.csv` , along with the following table detailing the column names and descriptions. This data does contain null values and some outliers, but handling these is out of scope for the project. Feel free to experiment after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Start coding!
netflix_df = pd.read_csv('netflix_data.csv')
netflix_df.head()
# Out:
#   show_id  ...             genre
# 0      s1  ...  International TV
# 1      s2  ...            Dramas
# 2      s3  ...     Horror Movies
# 3      s4  ...            Action
# 4      s5  ...            Dramas
#
# [5 rows x 11 columns]

# %%
netflix_subset = netflix_df[netflix_df['type']!='TV Show']
netflix_subset
# Out:
#      show_id  ...          genre
# 1         s2  ...         Dramas
# 2         s3  ...  Horror Movies
# 3         s4  ...         Action
# 4         s5  ...         Dramas
# 6         s7  ...  Horror Movies
# ...      ...  ...            ...
# 7781   s7782  ...       Children
# 7782   s7783  ...         Dramas
# 7783   s7784  ...         Dramas
# 7784   s7785  ...  Documentaries
# 7786   s7787  ...  Documentaries
#
# [5377 rows x 11 columns]

# %%
columns_selected = ['title','country','genre','release_year','duration']
netflix_movies = netflix_subset[columns_selected]
netflix_movies
# Out:
#                                         title  ... duration
# 1                                        7:19  ...       93
# 2                                       23:59  ...       78
# 3                                           9  ...       80
# 4                                          21  ...      123
# 6                                         122  ...       95
# ...                                       ...  ...      ...
# 7781                                     Zoom  ...       88
# 7782                                     Zozo  ...       99
# 7783                                   Zubaan  ...      111
# 7784                        Zulu Man in Japan  ...       44
# 7786  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  ...       90
#
# [5377 rows x 5 columns]

# %%
short_movies = netflix_movies[netflix_movies['duration']<60]
short_movies
# Out:
#                                                   title  ... duration
# 35                                            #Rucker50  ...       56
# 55                  100 Things to do Before High School  ...       44
# 67    13TH: A Conversation with Oprah Winfrey & Ava ...  ...       37
# 101                                   3 Seconds Divorce  ...       53
# 146                                      A 3 Minute Hug  ...       28
# ...                                                 ...  ...      ...
# 7679                    WWII: Report from the Aleutians  ...       45
# 7692  Ya no estoy aquí: Una conversación entre Guill...  ...       15
# 7718                     Yoo Byung Jae: Discomfort Zone  ...       54
# 7771                                               Zion  ...       12
# 7784                                  Zulu Man in Japan  ...       44
#
# [420 rows x 5 columns]

# %%
colors = []

for index, row in netflix_movies.iterrows():
    if row['genre'] == 'Children':
        colors.append('blue')
    elif row['genre'] == 'Documentaries':
        colors.append('green')
    elif row['genre'] == 'Stand-Up':
        colors.append('red')
    else:
        colors.append('gray')

print(colors)
# Out:
# ['gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'gray', 'green', 'green', 'gray', 'gray', 'gray', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'gray', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'gray', 'gray', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'blue', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'blue', 'green', 'blue', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'blue', 'gray', 'gray', 'gray', 'blue', 'blue', 'blue', 'gray', 'blue', 'blue', 'gray', 'gray', 'blue', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'blue', 'blue', 'blue', 'green', 'green', 'gray', 'gray', 'gray', 'blue', 'gray', 'green', 'gray', 'gray', 'green', 'green', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'blue', 'gray', 'red', 'gray', 'gray', 'green', 'gray', 'gray', 'blue', 'gray', 'gray', 'gray', 'gray', 'gray', 'blue', 'gray', 'gray', 'green', 'gray', 'gray', 'blue', 'gray', 'blue', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'gray', 'blue', 'blue', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'gray', 'gray', 'blue', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'blue', 'gray', 'gray', 'gray', 'red', 'red', 'gray', 'gray', 'red', 'gray', 'red', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'red', 'gray', 'green', 'green', 'green', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'red', 'gray', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'red', 'gray', 'gray', 'gray', 'blue', 'red', 'green', 'gray', 'red', 'gray', 'gray', 'gray', 'green', 'gray', 'gray', 'red', 'red', 'gray', 'green', 'gray', 'gray', 'gray', 'green', 'gray', 'blue', 'blue', 'green', 'gray', 'gray', 'gray', 'gray', 'blue', 'gray', 'blue', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'blue', 'blue', 'green', 'green', 'gray', 'gray', 'gray', 'green', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'green', 'gray', 'gray', 'green', 'green', 'green', 'green', 'green', 'gray', 'gray', 'gray', 'gray', 'green', 'green', 'gray', 'gray', 'gray', 'gray', 'red', 'gray', 'gray', 'green', 'red', 'red', 'green', 'blue', 'blue', 'blue', 'blue', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'green', 'gray', 'gray', 'gray', 'gray', 'blue', 'blue', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'blue', 'gray', 'gray', 'gray', 'red', 'gray', 'gray', 'blue', 'gray', 'gray', 'gray', 'gray', 'blue', 'red', 'red', 'gray', 'gray', 'green', 'gray', 'green', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'red', 'blue', 'gray', 'gray', 'red', 'green', 'gray', 'gray', 'gray', 'red', 'gray', 'blue', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'gray', 'green', 'gray', 'gray', 'gray', 'green', 'gray', 'green', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'green',  ...

# %%
fig, ax = plt.subplots()
ax.scatter(netflix_movies['release_year'], netflix_movies['duration'], c=colors)

ax.set_xlabel('Release year')
ax.set_ylabel('Duration (min)')
ax.set_title('Movie Duration by Year of Release')

plt.show()

# %%
answer = 'no'
